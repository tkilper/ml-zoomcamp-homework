# %%
# ML Zoomcamp Module 5 Homework - Tristan Kilper

# %%
import pickle

# %%
# Q1

# %%
# (installed uv version 0.10.0)

# %%
# Q2

# %%
hash = 'sha256:9bccbb3b40e3de10351f8f5068e105d0f4083b1a65fa07b6634fbc401a6287fd'

# %%
# Q3

# %%
input_file = 'pipeline_v1.bin'

with open(input_file, 'rb') as f_in:
    (dv, model) = pickle.load(f_in)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator DictVectorizer from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
customer = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

# %%
X = dv.transform([customer])

# %%
model.predict_proba(X)[0,1]
# Out:
# np.float64(0.5336072702798061)

# %%
# Q4

# %%
import requests

# %%
url = "http://localhost:9696/predict"
customer = {
    "lead_source": "organic_search",
    "number_of_courses_viewed": 4,
    "annual_income": 80304.0
}
response = requests.post(url, json=customer)
print(response.json())
# Out:
# {'subscribe_probability': 0.5340417283801275}

# %%
# Q5

# %%
# 121 MB

# %%
# 6

# %%
# 0.99
